# %%
import os
import pandas as pd
from scipy.stats import fisher_exact

# %%
experiments = []

# %%
def create_subject():
    table = pd.read_table('geneName.txt')['Unknown']
    subject = table.value_counts().index.tolist()[1:]
    return subject

def create_gene_sets():
    gene_sets = []
    for f in os.listdir('data'):
        if f.endswith('.txt'):
            gene_sets.append(f)
    return gene_sets

def create_gene_set(set_name):
    with open('data/' + set_name) as f:
        gene_set= f.readlines()
    return [line.strip() for line in gene_set]


def create_all_genes():
    with open('all') as f:
        all_genes = f.readlines()
    return [line.strip() for line in all_genes]

# %%
def contingency_matrix(subject, gene_set, all_genes):
    a, b, c, d = [], [], [], []
    for gene in subject:
        if gene in gene_set:
            a.append(gene)
        else:
            b.append(gene)
    for gene in gene_set:
        if gene not in subject:
            c.append(gene)
    for gene in all_genes:
        if gene not in subject and gene not in gene_set:
            d.append(gene)
    return a, b, c, d

# %%
subject = create_subject()
gene_sets = create_gene_sets()
all_genes = create_all_genes()

# %%
for set_name in gene_sets:
    experiment = []
    gene_set = create_gene_set(set_name)
    title = gene_set[0]
    description = gene_set[1]
    genes = gene_set[2:]
    a, b, c, d = contingency_matrix(subject, genes, all_genes)
    experiment.append(title) # 0
    experiment.append(description) # 1
    experiment.append([[a, b], [c, d]]) # 2
    experiment.append([[len(a), len(b)], [len(c), len(d)]]) # 3
    oddsratio, p_value = fisher_exact(experiment[3])
    experiment.append(p_value) # 4
    experiments.append(experiment)

# %%
df = pd.DataFrame(experiments)
df
# Out:
#                                              0  \
# 0                        HALLMARK_ADIPOGENESIS
# 1                 HALLMARK_ALLOGRAFT_REJECTION
# 2                   HALLMARK_ANDROGEN_RESPONSE
# 3                        HALLMARK_ANGIOGENESIS
# 4                     HALLMARK_APICAL_JUNCTION
# 5                      HALLMARK_APICAL_SURFACE
# 6                           HALLMARK_APOPTOSIS
# 7                HALLMARK_BILE_ACID_METABOLISM
# 8             HALLMARK_CHOLESTEROL_HOMEOSTASIS
# 9                         HALLMARK_COAGULATION
# 10                         HALLMARK_COMPLEMENT
# 11                         HALLMARK_DNA_REPAIR
# 12                        HALLMARK_E2F_TARGETS
# 13  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 14            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 15             HALLMARK_ESTROGEN_RESPONSE_LATE
# 16              HALLMARK_FATTY_ACID_METABOLISM
# 17                     HALLMARK_G2M_CHECKPOINT
# 18                         HALLMARK_GLYCOLYSIS
# 19                 HALLMARK_HEDGEHOG_SIGNALING
# 20                    HALLMARK_HEME_METABOLISM
# 21                            HALLMARK_HYPOXIA
# 22                HALLMARK_IL2_STAT5_SIGNALING
# 23            HALLMARK_IL6_JAK_STAT3_SIGNALING
# 24              HALLMARK_INFLAMMATORY_RESPONSE
# 25          HALLMARK_INTERFERON_ALPHA_RESPONSE
# 26          HALLMARK_INTERFERON_GAMMA_RESPONSE
# 27                  HALLMARK_KRAS_SIGNALING_DN
# 28                  HALLMARK_KRAS_SIGNALING_UP
# 29                    HALLMARK_MITOTIC_SPINDLE
# 30                   HALLMARK_MTORC1_SIGNALING
# 31                     HALLMARK_MYC_TARGETS_V1
# 32                     HALLMARK_MYC_TARGETS_V2
# 33                         HALLMARK_MYOGENESIS
# 34                    HALLMARK_NOTCH_SIGNALING
# 35          HALLMARK_OXIDATIVE_PHOSPHORYLATION
# 36                        HALLMARK_P53_PATHWAY
# 37                HALLMARK_PANCREAS_BETA_CELLS
# 38                         HALLMARK_PEROXISOME
# 39            HALLMARK_PI3K_AKT_MTOR_SIGNALING
# 40                  HALLMARK_PROTEIN_SECRETION
# 41    HALLMARK_REACTIVE_OXIGEN_SPECIES_PATHWAY
# 42                    HALLMARK_SPERMATOGENESIS
# 43                 HALLMARK_TGF_BETA_SIGNALING
# 44            HALLMARK_TNFA_SIGNALING_VIA_NFKB
# 45          HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# 46                     HALLMARK_UV_RESPONSE_DN
# 47                     HALLMARK_UV_RESPONSE_UP
# 48         HALLMARK_WNT_BETA_CATENIN_SIGNALING
# 49              HALLMARK_XENOBIOTIC_METABOLISM
#
#                                                     1  \
# 0   > Genes up-regulated during adipocyte differen...
# 1   > Genes up-regulated during transplant rejection.
# 2             > Genes defining response to androgens.
# 3   > Genes up-regulated during formation of blood...
# 4   > Genes encoding components of apical junction...
# 5   > Genes encoding proteins over-represented on ...
# 6   > Genes mediating programmed cell death (apopt...
# 7   > Genes involve in metabolism of bile acids an...
# 8        > Genes involved in cholesterol homeostasis.
# 9   > Genes encoding components of blood coagulati...
# 10  > Genes encoding components of the complement ...
# 11                    > Genes involved in DNA repair.
# 12  > Genes encoding cell cycle related targets of...
# 13  > Genes defining epithelial-mesenchymal transi...
# 14       > Genes defining early response to estrogen.
# 15        > Genes defining late response to estrogen.
# 16  > Genes encoding proteins involved in metaboli...
# 17  > Genes involved in the G2/M checkpoint, as in...
# 18  > Genes encoding proteins involved in glycolys...
# 19  > Genes up-regulated by activation of hedgehog...
# 20  > Genes involved in metabolism of heme (a cofa...
# 21  > Genes up-regulated in response to low oxygen...
# 22  > Genes up-regulated by STAT5 in response to I...
# 23  > Genes up-regulated by IL6 [GeneID=3569] via ...
# 24            > Genes defining inflammatory response.
# 25  > Genes up-regulated in response to alpha inte...
# 26  > Genes up-regulated in response to IFNG [Gene...
# 27         > Genes down-regulated by KRAS activation.
# 28           > Genes up-regulated by KRAS activation.
# 29    > Genes important for mitotic spindle assembly.
# 30  > Genes up-regulated through activation of mTO...
# 31  > A subgroup of genes regulated by MYC - versi...
# 32  > A subgroup of genes regulated by MYC - versi...
# 33  > Genes involved in development of skeletal mu...
# 34  > Genes up-regulated by activation of Notch si...
# 35  > Genes encoding proteins involved in oxidativ...
# 36     > Genes involved in p53 pathways and networks.
# 37  > Genes specifically up-regulated in pancreati...
# 38         > Genes encoding components of peroxisome.
# 39  > Genes up-regulated by activation of the PI3K...
# 40     > Genes involved in protein secretion pathway.
# 41  > Genes up-regulated by reactive oxigen specie...
# 42  > Genes up-regulated during production of male...
# 43  > Genes up-regulated in response to TGFB1 [Gen...
# 44  > Genes regulated by NF-kB in response to TNF ...
# 45  > Genes up-regulated during unfolded protein r...
# 46  > Genes down-regulated in response to ultravio...
# 47  > Genes up-regulated in response to ultraviole...
# 48  > Genes up-regulated by activation of WNT sign...
# 49  > Genes encoding proteins involved in processi...
#
#                                                     2                       3  \
# 0   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 1   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 2   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [101, 4286]]
# 3   [[[PDGFA], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA...   [[1, 59], [35, 4351]]
# 4   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 5   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [44, 4341]]
# 6   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [161, 4225]]
# 7   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [112, 4273]]
# 8   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [74, 4311]]
# 9   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [138, 4249]]
# 10  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 11  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [150, 4237]]
# 12  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 13  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 14  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 15  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4185]]
# 16  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [158, 4228]]
# 17  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4185]]
# 18  [[[CHST12], [SDK1, MAD1L1, PRKAR1B, CARD11, GN...  [[1, 59], [199, 4188]]
# 19  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [36, 4349]]
# 20  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 21  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 22  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 23  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [87, 4300]]
# 24  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 25  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [97, 4289]]
# 26  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 27  [[[LFNG], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA1...  [[1, 59], [199, 4188]]
# 28  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 29  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4185]]
# 30  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 31  [[[EIF3B], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA...  [[1, 59], [199, 4187]]
# 32  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [58, 4328]]
# 33  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4185]]
# 34  [[[LFNG], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA1...   [[1, 59], [31, 4356]]
# 35  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 36  [[[PDGFA], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA...  [[1, 59], [199, 4188]]
# 37  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [40, 4345]]
# 38  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [104, 4282]]
# 39  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [105, 4281]]
# 40  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [96, 4290]]
# 41  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [49, 4338]]
# 42  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [135, 4251]]
# 43  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [54, 4333]]
# 44  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4185]]
# 45  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [113, 4274]]
# 46  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [144, 4243]]
# 47  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [158, 4228]]
# 48  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [42, 4344]]
# 49  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
#
#            4
# 0   0.113194
# 1   0.113188
# 2   0.647125
# 3   0.388039
# 4   0.113194
# 5   1.000000
# 6   0.278864
# 7   0.405679
# 8   0.626499
# 9   0.263430
# 10  0.113194
# 11  0.268677
# 12  0.113194
# 13  0.113188
# 14  0.113188
# 15  0.113200
# 16  0.275630
# 17  0.113200
# 18  0.523257
# 19  1.000000
# 20  0.113188
# 21  0.113194
# 22  0.113194
# 23  0.632056
# 24  0.113194
# 25  0.642092
# 26  0.113188
# 27  0.523257
# 28  0.113188
# 29  0.113200
# 30  0.113194
# 31  0.523283
# 32  1.000000
# 33  0.113200
# 34  0.353527
# 35  0.113194
# 36  0.523257
# 37  1.000000
# 38  0.403941
# 39  0.403938
# 40  0.640912
# 41  1.000000
# 42  0.263177
# 43  1.000000
# 44  0.113200
# 45  0.406141
# 46  0.265238
# 47  0.275630
# 48  1.000000
# 49  0.113194

# %%
df.sort_values(4, axis=0)
# Out:
#                                              0  \
# 1                 HALLMARK_ALLOGRAFT_REJECTION
# 28                  HALLMARK_KRAS_SIGNALING_UP
# 26          HALLMARK_INTERFERON_GAMMA_RESPONSE
# 20                    HALLMARK_HEME_METABOLISM
# 14            HALLMARK_ESTROGEN_RESPONSE_EARLY
# 13  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION
# 0                        HALLMARK_ADIPOGENESIS
# 35          HALLMARK_OXIDATIVE_PHOSPHORYLATION
# 30                   HALLMARK_MTORC1_SIGNALING
# 22                HALLMARK_IL2_STAT5_SIGNALING
# 21                            HALLMARK_HYPOXIA
# 12                        HALLMARK_E2F_TARGETS
# 24              HALLMARK_INFLAMMATORY_RESPONSE
# 10                         HALLMARK_COMPLEMENT
# 4                     HALLMARK_APICAL_JUNCTION
# 49              HALLMARK_XENOBIOTIC_METABOLISM
# 17                     HALLMARK_G2M_CHECKPOINT
# 33                         HALLMARK_MYOGENESIS
# 15             HALLMARK_ESTROGEN_RESPONSE_LATE
# 44            HALLMARK_TNFA_SIGNALING_VIA_NFKB
# 29                    HALLMARK_MITOTIC_SPINDLE
# 42                    HALLMARK_SPERMATOGENESIS
# 9                         HALLMARK_COAGULATION
# 46                     HALLMARK_UV_RESPONSE_DN
# 11                         HALLMARK_DNA_REPAIR
# 16              HALLMARK_FATTY_ACID_METABOLISM
# 47                     HALLMARK_UV_RESPONSE_UP
# 6                           HALLMARK_APOPTOSIS
# 34                    HALLMARK_NOTCH_SIGNALING
# 3                        HALLMARK_ANGIOGENESIS
# 39            HALLMARK_PI3K_AKT_MTOR_SIGNALING
# 38                         HALLMARK_PEROXISOME
# 7                HALLMARK_BILE_ACID_METABOLISM
# 45          HALLMARK_UNFOLDED_PROTEIN_RESPONSE
# 18                         HALLMARK_GLYCOLYSIS
# 27                  HALLMARK_KRAS_SIGNALING_DN
# 36                        HALLMARK_P53_PATHWAY
# 31                     HALLMARK_MYC_TARGETS_V1
# 8             HALLMARK_CHOLESTEROL_HOMEOSTASIS
# 23            HALLMARK_IL6_JAK_STAT3_SIGNALING
# 40                  HALLMARK_PROTEIN_SECRETION
# 25          HALLMARK_INTERFERON_ALPHA_RESPONSE
# 2                   HALLMARK_ANDROGEN_RESPONSE
# 5                      HALLMARK_APICAL_SURFACE
# 41    HALLMARK_REACTIVE_OXIGEN_SPECIES_PATHWAY
# 43                 HALLMARK_TGF_BETA_SIGNALING
# 48         HALLMARK_WNT_BETA_CATENIN_SIGNALING
# 19                 HALLMARK_HEDGEHOG_SIGNALING
# 37                HALLMARK_PANCREAS_BETA_CELLS
# 32                     HALLMARK_MYC_TARGETS_V2
#
#                                                     1  \
# 1   > Genes up-regulated during transplant rejection.
# 28           > Genes up-regulated by KRAS activation.
# 26  > Genes up-regulated in response to IFNG [Gene...
# 20  > Genes involved in metabolism of heme (a cofa...
# 14       > Genes defining early response to estrogen.
# 13  > Genes defining epithelial-mesenchymal transi...
# 0   > Genes up-regulated during adipocyte differen...
# 35  > Genes encoding proteins involved in oxidativ...
# 30  > Genes up-regulated through activation of mTO...
# 22  > Genes up-regulated by STAT5 in response to I...
# 21  > Genes up-regulated in response to low oxygen...
# 12  > Genes encoding cell cycle related targets of...
# 24            > Genes defining inflammatory response.
# 10  > Genes encoding components of the complement ...
# 4   > Genes encoding components of apical junction...
# 49  > Genes encoding proteins involved in processi...
# 17  > Genes involved in the G2/M checkpoint, as in...
# 33  > Genes involved in development of skeletal mu...
# 15        > Genes defining late response to estrogen.
# 44  > Genes regulated by NF-kB in response to TNF ...
# 29    > Genes important for mitotic spindle assembly.
# 42  > Genes up-regulated during production of male...
# 9   > Genes encoding components of blood coagulati...
# 46  > Genes down-regulated in response to ultravio...
# 11                    > Genes involved in DNA repair.
# 16  > Genes encoding proteins involved in metaboli...
# 47  > Genes up-regulated in response to ultraviole...
# 6   > Genes mediating programmed cell death (apopt...
# 34  > Genes up-regulated by activation of Notch si...
# 3   > Genes up-regulated during formation of blood...
# 39  > Genes up-regulated by activation of the PI3K...
# 38         > Genes encoding components of peroxisome.
# 7   > Genes involve in metabolism of bile acids an...
# 45  > Genes up-regulated during unfolded protein r...
# 18  > Genes encoding proteins involved in glycolys...
# 27         > Genes down-regulated by KRAS activation.
# 36     > Genes involved in p53 pathways and networks.
# 31  > A subgroup of genes regulated by MYC - versi...
# 8        > Genes involved in cholesterol homeostasis.
# 23  > Genes up-regulated by IL6 [GeneID=3569] via ...
# 40     > Genes involved in protein secretion pathway.
# 25  > Genes up-regulated in response to alpha inte...
# 2             > Genes defining response to androgens.
# 5   > Genes encoding proteins over-represented on ...
# 41  > Genes up-regulated by reactive oxigen specie...
# 43  > Genes up-regulated in response to TGFB1 [Gen...
# 48  > Genes up-regulated by activation of WNT sign...
# 19  > Genes up-regulated by activation of hedgehog...
# 37  > Genes specifically up-regulated in pancreati...
# 32  > A subgroup of genes regulated by MYC - versi...
#
#                                                     2                       3  \
# 1   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 28  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 26  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 20  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 14  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 13  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4187]]
# 0   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 35  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 30  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 22  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 21  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 12  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 24  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 10  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 4   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 49  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4186]]
# 17  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4185]]
# 33  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4185]]
# 15  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4185]]
# 44  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4185]]
# 29  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [200, 4185]]
# 42  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [135, 4251]]
# 9   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [138, 4249]]
# 46  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [144, 4243]]
# 11  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [150, 4237]]
# 16  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [158, 4228]]
# 47  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [158, 4228]]
# 6   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [161, 4225]]
# 34  [[[LFNG], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA1...   [[1, 59], [31, 4356]]
# 3   [[[PDGFA], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA...   [[1, 59], [35, 4351]]
# 39  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [105, 4281]]
# 38  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [104, 4282]]
# 7   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [112, 4273]]
# 45  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [113, 4274]]
# 18  [[[CHST12], [SDK1, MAD1L1, PRKAR1B, CARD11, GN...  [[1, 59], [199, 4188]]
# 27  [[[LFNG], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA1...  [[1, 59], [199, 4188]]
# 36  [[[PDGFA], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA...  [[1, 59], [199, 4188]]
# 31  [[[EIF3B], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA...  [[1, 59], [199, 4187]]
# 8   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [74, 4311]]
# 23  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [87, 4300]]
# 40  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [96, 4290]]
# 25  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [97, 4289]]
# 2   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...  [[0, 60], [101, 4286]]
# 5   [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [44, 4341]]
# 41  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [49, 4338]]
# 43  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [54, 4333]]
# 48  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [42, 4344]]
# 19  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [36, 4349]]
# 37  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [40, 4345]]
# 32  [[[], [SDK1, MAD1L1, PRKAR1B, CARD11, GNA12, S...   [[0, 60], [58, 4328]]
#
#            4
# 1   0.113188
# 28  0.113188
# 26  0.113188
# 20  0.113188
# 14  0.113188
# 13  0.113188
# 0   0.113194
# 35  0.113194
# 30  0.113194
# 22  0.113194
# 21  0.113194
# 12  0.113194
# 24  0.113194
# 10  0.113194
# 4   0.113194
# 49  0.113194
# 17  0.113200
# 33  0.113200
# 15  0.113200
# 44  0.113200
# 29  0.113200
# 42  0.263177
# 9   0.263430
# 46  0.265238
# 11  0.268677
# 16  0.275630
# 47  0.275630
# 6   0.278864
# 34  0.353527
# 3   0.388039
# 39  0.403938
# 38  0.403941
# 7   0.405679
# 45  0.406141
# 18  0.523257
# 27  0.523257
# 36  0.523257
# 31  0.523283
# 8   0.626499
# 23  0.632056
# 40  0.640912
# 25  0.642092
# 2   0.647125
# 5   1.000000
# 41  1.000000
# 43  1.000000
# 48  1.000000
# 19  1.000000
# 37  1.000000
# 32  1.000000
